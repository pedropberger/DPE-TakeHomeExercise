# %%
import requests
import pandas as pd

# URL to fetch data
url = "http://oscars.yipitdata.com/"

# Fetch data from URL
response = requests.get(url)
data = response.json()

# Initialize an empty list to store rows
rows = []

# Loop over each year's data and extract film information
for entry in data['results']:
    year = entry['year']
    films = entry['films']
    
    for film in films:
        row = {
            "Year": year,
            "Film": film['Film'],
            "Producer(s)": film["Producer(s)"],
            "Production Company(s)": film["Production Company(s)"],
            "Winner": film["Winner"],
            "Detail URL": film["Detail URL"],
            "Wiki URL": film["Wiki URL"]
        }
        rows.append(row)

# Convert the list of rows into a DataFrame
df = pd.DataFrame(rows)

# Display the DataFrame
print(df.head())

# %%
import requests
import pandas as pd

# URL to fetch data
url = "http://oscars.yipitdata.com/"

# Fetch data from URL
response = requests.get(url)
data = response.json()

# Use json_normalize to flatten the JSON structure
df = pd.json_normalize(data['results'], 'films', ['year'])

# Show the first few rows of the DataFrame
#print(df.head())

# %%
import requests
import pandas as pd

def fetch_budget(url):
    try:
        # Get the JSON content from the URL
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        
        # Load the JSON data
        data = response.json()
        
        # Extract the 'Budget' field
        budget = data.get("Budget", None)  # Returns None if 'Budget' is not found
        return budget
    except Exception as e:
        print(f"Error fetching data from {url}: {e}")
        return None

def add_budget_column(df):
    # Apply the fetch_budget function to each row of the 'Detail URL' column
    df['Budget'] = df['Detail URL'].apply(fetch_budget)
    return df

# Assuming 'oscar' is the dataframe you're working with
# Example usage:
oscar = add_budget_column(df)


# The 'oscar' dataframe will now have a new 'Budget' column with the extracted data

oscar.head()

oscar_backup = oscar.copy()
# Out:
# Error fetching data from http://oscars.yipitdata.com/films/Les_Mis%C3%A9rables_(1935_film): 403 Client Error: Forbidden for url: http://oscars.yipitdata.com/films/Les_Mis%C3%A9rables_(1935_film)
# Error fetching data from http://oscars.yipitdata.com/films/Who%2527s_Afraid_of_Virginia_Woolf%3F_(film): 403 Client Error: Forbidden for url: http://oscars.yipitdata.com/films/Who%2527s_Afraid_of_Virginia_Woolf%3F_(film)
# Error fetching data from http://oscars.yipitdata.com/films/Secrets_%26_Lies_(film): 403 Client Error: Forbidden for url: http://oscars.yipitdata.com/films/Secrets_%26_Lies_(film)
# Error fetching data from http://oscars.yipitdata.com/films/Les_Mis%C3%A9rables_(2012_film): 403 Client Error: Forbidden for url: http://oscars.yipitdata.com/films/Les_Mis%C3%A9rables_(2012_film)

# %%
oscar_backup.head()
# Out:
#                                           Detail URL                 Film  \
# 0  http://oscars.yipitdata.com/films/Wings_(1927_...                Wings
# 1  http://oscars.yipitdata.com/films/The_Racket_(...           The Racket
# 2  http://oscars.yipitdata.com/films/Seventh_Heav...       Seventh Heaven
# 3  http://oscars.yipitdata.com/films/The_Broadway...  The Broadway Melody
# 4  http://oscars.yipitdata.com/films/Alibi_(1929_...                Alibi
#
#                              Producer(s)  \
# 0                         Lucien Hubbard
# 1                          Howard Hughes
# 2                            William Fox
# 3  Irving Thalberg & Lawrence Weingarten
# 4                            Roland West
#
#                   Production Company(s)  \
# 0      Paramount , Famous Players-Lasky
# 1                      Paramount, Caddo
# 2                                   Fox
# 3              Metro-Goldwyn-Mayer  [L]
# 4  United Artists , Feature Productions
#
#                                             Wiki URL  Winner  \
# 0     http://en.wikipedia.org/wiki/Wings_(1927_film)    True
# 1  http://en.wikipedia.org/wiki/The_Racket_(1928_...   False
# 2  http://en.wikipedia.org/wiki/Seventh_Heaven_(1...   False
# 3   http://en.wikipedia.org/wiki/The_Broadway_Melody    True
# 4     http://en.wikipedia.org/wiki/Alibi_(1929_film)   False
#
#                    year               Budget
# 0  1927 / 28 [A]  (1st)  US$ 2 million [ 4 ]
# 1  1927 / 28 [A]  (1st)                 None
# 2  1927 / 28 [A]  (1st)   $1.3 million [ 1 ]
# 3      1928 / 29  (2nd)                 None
# 4      1928 / 29  (2nd)                 None

# %%
oscar.to_excel('output/oscar.xlsx')

# %%
oscar = oscar_backup.copy()

# %%
oscar.head()
# Out:
#                                           Detail URL                 Film  \
# 0  http://oscars.yipitdata.com/films/Wings_(1927_...                Wings
# 1  http://oscars.yipitdata.com/films/The_Racket_(...           The Racket
# 2  http://oscars.yipitdata.com/films/Seventh_Heav...       Seventh Heaven
# 3  http://oscars.yipitdata.com/films/The_Broadway...  The Broadway Melody
# 4  http://oscars.yipitdata.com/films/Alibi_(1929_...                Alibi
#
#                              Producer(s)  \
# 0                         Lucien Hubbard
# 1                          Howard Hughes
# 2                            William Fox
# 3  Irving Thalberg & Lawrence Weingarten
# 4                            Roland West
#
#                   Production Company(s)  \
# 0      Paramount , Famous Players-Lasky
# 1                      Paramount, Caddo
# 2                                   Fox
# 3              Metro-Goldwyn-Mayer  [L]
# 4  United Artists , Feature Productions
#
#                                             Wiki URL  Winner  \
# 0     http://en.wikipedia.org/wiki/Wings_(1927_film)    True
# 1  http://en.wikipedia.org/wiki/The_Racket_(1928_...   False
# 2  http://en.wikipedia.org/wiki/Seventh_Heaven_(1...   False
# 3   http://en.wikipedia.org/wiki/The_Broadway_Melody    True
# 4     http://en.wikipedia.org/wiki/Alibi_(1929_film)   False
#
#                    year               Budget
# 0  1927 / 28 [A]  (1st)  US$ 2 million [ 4 ]
# 1  1927 / 28 [A]  (1st)                 None
# 2  1927 / 28 [A]  (1st)   $1.3 million [ 1 ]
# 3      1928 / 29  (2nd)                 None
# 4      1928 / 29  (2nd)                 None

# %%
import pandas as pd
import numpy as np
import re

# Sample data
# Assuming 'oscar' is the dataframe and 'Budget' is the original column.

# Conversion rates (example values, adjust if necessary)
conversion_rates = {
    '£': 1.35,   # Example: 1 GBP = 1.35 USD
    '€': 1.18,   # Example: 1 EUR = 1.18 USD
    '₤': 1.35    # Treating '₤' as GBP for now
}

# Removes all characters from 'or' including itself in the specified column, and create a temporary column to work with
oscar['Budget_aux'] = oscar['Budget'].str.split('or', expand = True)[0]

# Helper function to convert non-USD values to USD
def convert_to_usd(amount, currency_symbol):
    if currency_symbol in conversion_rates:
        return amount * conversion_rates[currency_symbol]
    return amount

# Helper function to clean up budget
def clean_budget(budget):
    if pd.isna(budget):  # If NaN, return 0
        return 0

    # Remove unnecessary symbols like brackets, estimations, etc.
    budget = re.sub(r'\[.*?\]', '', str(budget)).strip()
    budget = re.sub(r'\(.*?\)', '', budget).strip()

    # Handle ranges (e.g., "$1.2 million - $2.275 million")
    if '–' in budget or '-' in budget:
        budget_parts = budget.split('–')[0].split('-')[0].strip()
        if 'million' in budget.lower():
            budget = budget_parts + ' million'
        else:
            budget = budget_parts


    # Identify the currency symbol and value
    currency_symbol = None
    if budget.startswith('US$') or budget.startswith('$'):
        currency_symbol = '$'
        budget = budget.replace('US$', '').replace('$', '').strip()
    elif budget.startswith('£'):
        currency_symbol = '£'
        budget = budget.replace('£', '').strip()
    elif budget.startswith('€'):
        currency_symbol = '€'
        budget = budget.replace('€', '').strip()
    elif budget.startswith('₤'):
        currency_symbol = '₤'
        budget = budget.replace('₤', '').strip()

    # Handle values like "million" or "billion"
    if 'million' in budget.lower():
        budget_value = float(re.sub(r'[^\d.]', '', budget)) * 1_000_000
    elif 'billion' in budget.lower():
        budget_value = float(re.sub(r'[^\d.]', '', budget)) * 1_000_000_000
    else:
        budget_value = float(re.sub(r'[^\d]', '', budget))  # Remove non-numeric characters

    # Convert to USD if necessary
    if currency_symbol and currency_symbol != '$':
        budget_value = convert_to_usd(budget_value, currency_symbol)

    return int(budget_value)


# Apply cleaning function to 'Budget' column
oscar['Budget_converted_to_USD'] = oscar['Budget_aux'].apply(clean_budget)

oscar.drop('Budget_aux', axis=1, inplace=True)

x = '$1.3 million [ 1 ]'
y = '$1,180,280'
z = '$10.500.000'
a = '$16.5-18 million [ 2 ] [ 3 ]'
b = '$1.2 million - $2.275 million'

print(clean_budget(x))
print(clean_budget(y))
print(clean_budget(z))
print(clean_budget(a))
print(clean_budget(b))

# Now the oscar dataframe will have a new column 'Budget_OK' with cleaned budget values.
# Out:
# 1300000
# 1180280
# 10500000
# 16500000
# 1200000

# %%
oscar.head()
# Out:
#                                           Detail URL                 Film  \
# 0  http://oscars.yipitdata.com/films/Wings_(1927_...                Wings
# 1  http://oscars.yipitdata.com/films/The_Racket_(...           The Racket
# 2  http://oscars.yipitdata.com/films/Seventh_Heav...       Seventh Heaven
# 3  http://oscars.yipitdata.com/films/The_Broadway...  The Broadway Melody
# 4  http://oscars.yipitdata.com/films/Alibi_(1929_...                Alibi
#
#                              Producer(s)  \
# 0                         Lucien Hubbard
# 1                          Howard Hughes
# 2                            William Fox
# 3  Irving Thalberg & Lawrence Weingarten
# 4                            Roland West
#
#                   Production Company(s)  \
# 0      Paramount , Famous Players-Lasky
# 1                      Paramount, Caddo
# 2                                   Fox
# 3              Metro-Goldwyn-Mayer  [L]
# 4  United Artists , Feature Productions
#
#                                             Wiki URL  Winner  \
# 0     http://en.wikipedia.org/wiki/Wings_(1927_film)    True
# 1  http://en.wikipedia.org/wiki/The_Racket_(1928_...   False
# 2  http://en.wikipedia.org/wiki/Seventh_Heaven_(1...   False
# 3   http://en.wikipedia.org/wiki/The_Broadway_Melody    True
# 4     http://en.wikipedia.org/wiki/Alibi_(1929_film)   False
#
#                    year               Budget  Budget_converted_to_USD
# 0  1927 / 28 [A]  (1st)  US$ 2 million [ 4 ]                  2000000
# 1  1927 / 28 [A]  (1st)                 None                        0
# 2  1927 / 28 [A]  (1st)   $1.3 million [ 1 ]                  1300000
# 3      1928 / 29  (2nd)                 None                        0
# 4      1928 / 29  (2nd)                 None                        0

# %%
oscar.to_excel('output/oscar_budget_corrigido.xlsx')

# %%
# Function to extract 'year_simple' and 'edition'
def clean_year_column(row):
    # Extract the year part (e.g., '1927 / 28' -> '1927', '1928', etc.)
    year_match = re.search(r'(\d{4})', row)
    year_simple = year_match.group(1) if year_match else None
    
    # Extract the edition number (e.g., '(1st)', '(2nd)', etc.)
    edition_match = re.search(r'\((\d+)(?:st|nd|rd|th)\)', row)
    edition = edition_match.group(1) if edition_match else None
    
    return pd.Series([year_simple, edition])

# Apply the function to the 'year' column
oscar[['year_simple', 'Edition']] = oscar['year'].apply(clean_year_column)

oscar.head()
# Out:
#                                           Detail URL                 Film  \
# 0  http://oscars.yipitdata.com/films/Wings_(1927_...                Wings
# 1  http://oscars.yipitdata.com/films/The_Racket_(...           The Racket
# 2  http://oscars.yipitdata.com/films/Seventh_Heav...       Seventh Heaven
# 3  http://oscars.yipitdata.com/films/The_Broadway...  The Broadway Melody
# 4  http://oscars.yipitdata.com/films/Alibi_(1929_...                Alibi
#
#                              Producer(s)  \
# 0                         Lucien Hubbard
# 1                          Howard Hughes
# 2                            William Fox
# 3  Irving Thalberg & Lawrence Weingarten
# 4                            Roland West
#
#                   Production Company(s)  \
# 0      Paramount , Famous Players-Lasky
# 1                      Paramount, Caddo
# 2                                   Fox
# 3              Metro-Goldwyn-Mayer  [L]
# 4  United Artists , Feature Productions
#
#                                             Wiki URL  Winner  \
# 0     http://en.wikipedia.org/wiki/Wings_(1927_film)    True
# 1  http://en.wikipedia.org/wiki/The_Racket_(1928_...   False
# 2  http://en.wikipedia.org/wiki/Seventh_Heaven_(1...   False
# 3   http://en.wikipedia.org/wiki/The_Broadway_Melody    True
# 4     http://en.wikipedia.org/wiki/Alibi_(1929_film)   False
#
#                    year               Budget  Budget_converted_to_USD  \
# 0  1927 / 28 [A]  (1st)  US$ 2 million [ 4 ]                  2000000
# 1  1927 / 28 [A]  (1st)                 None                        0
# 2  1927 / 28 [A]  (1st)   $1.3 million [ 1 ]                  1300000
# 3      1928 / 29  (2nd)                 None                        0
# 4      1928 / 29  (2nd)                 None                        0
#
#   year_simple Edition
# 0        1927       1
# 1        1927       1
# 2        1927       1
# 3        1928       2
# 4        1928       2

# %%
oscar.to_excel('output/oscar_budget_corrigido_year.xlsx')

# %%
new_order = ['Film','Producer(s)','Production Company(s)','Winner','year','year_simple','Edition','Budget','Budget_converted_to_USD', 'Detail URL','Wiki URL']

oscar = oscar[new_order]

# %%
oscar.head()
# Out:
#                   Film                            Producer(s)  \
# 0                Wings                         Lucien Hubbard
# 1           The Racket                          Howard Hughes
# 2       Seventh Heaven                            William Fox
# 3  The Broadway Melody  Irving Thalberg & Lawrence Weingarten
# 4                Alibi                            Roland West
#
#                   Production Company(s)  Winner                  year  \
# 0      Paramount , Famous Players-Lasky    True  1927 / 28 [A]  (1st)
# 1                      Paramount, Caddo   False  1927 / 28 [A]  (1st)
# 2                                   Fox   False  1927 / 28 [A]  (1st)
# 3              Metro-Goldwyn-Mayer  [L]    True      1928 / 29  (2nd)
# 4  United Artists , Feature Productions   False      1928 / 29  (2nd)
#
#   year_simple Edition               Budget  Budget_converted_to_USD  \
# 0        1927       1  US$ 2 million [ 4 ]                  2000000
# 1        1927       1                 None                        0
# 2        1927       1   $1.3 million [ 1 ]                  1300000
# 3        1928       2                 None                        0
# 4        1928       2                 None                        0
#
#                                           Detail URL  \
# 0  http://oscars.yipitdata.com/films/Wings_(1927_...
# 1  http://oscars.yipitdata.com/films/The_Racket_(...
# 2  http://oscars.yipitdata.com/films/Seventh_Heav...
# 3  http://oscars.yipitdata.com/films/The_Broadway...
# 4  http://oscars.yipitdata.com/films/Alibi_(1929_...
#
#                                             Wiki URL
# 0     http://en.wikipedia.org/wiki/Wings_(1927_film)
# 1  http://en.wikipedia.org/wiki/The_Racket_(1928_...
# 2  http://en.wikipedia.org/wiki/Seventh_Heaven_(1...
# 3   http://en.wikipedia.org/wiki/The_Broadway_Melody
# 4     http://en.wikipedia.org/wiki/Alibi_(1929_film)
